# %% [markdown]
# 1. Image loading (four different methods)
#    * IPython.display
#    * Tensorflow.Keras API - Preprocessing
#    * Open CV
#    * PIL from pilo
# 2. Load Deep learning architectures
#     * Model Loading (MobileNet etc)
#     * Predictions
# 3. Decoding the predictions into labels

# %%
#importing libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
dirc='/Users/mdsanowarhossain/Documents/python/Deep_Learning/code_planet/cat.jpg'

# %%
dirc
# Out:
# '/Users/mdsanowarhossain/Documents/python/Deep_Learning/code_planet/cat.jpg'

# %% [markdown]
# # First method to load image

# %%
from IPython.display import Image
Image(filename=dirc,width=224,height=224)

# %% [markdown]
# # Second method to load image

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(dirc,target_size=(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x15B0E2D90>

# %%
plt.imshow(img)

# %% [markdown]
# # Thrid method to load an image

# %%
#this is best method
import cv2

# %%
# this is different color, this is GBR image not RGB
img=cv2.imread(dirc)
plt.imshow(img)

# %%
img2=cv2.resize(img,(100,100))
img2
# Out:
# array([[[ 20,  42,  60],
#         [ 24,  46,  64],
#         [ 20,  42,  60],
#         ...,
#         [ 19,  29,  42],
#         [ 17,  24,  39],
#         [ 22,  26,  37]],
#
#        [[ 18,  40,  58],
#         [ 22,  44,  62],
#         [ 20,  42,  60],
#         ...,
#         [ 34,  55,  71],
#         [ 13,  28,  47],
#         [ 34,  48,  65]],
#
#        [[ 17,  39,  57],
#         [ 19,  41,  59],
#         [ 17,  39,  57],
#         ...,
#         [ 20,  35,  55],
#         [ 13,  28,  44],
#         [ 36,  48,  59]],
#
#        ...,
#
#        [[ 92, 112, 123],
#         [ 65,  88, 102],
#         [ 49,  74,  90],
#         ...,
#         [ 41,  68,  89],
#         [ 49,  70,  92],
#         [ 50,  71,  93]],
#
#        [[ 77,  97, 108],
#         [ 64,  86, 101],
#         [ 54,  79,  95],
#         ...,
#         [ 50,  78,  95],
#         [ 49,  76,  97],
#         [ 47,  74,  95]],
#
#        [[ 73,  97, 115],
#         [ 57,  89, 105],
#         [ 60,  87, 104],
# ...

# %%
plt.imshow(img2)

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth Method to load an image

# %%
from PIL import Image

# %%
im=Image.open(dirc)

# %%
plt.imshow(im)

# %%
im=im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Load the deep learning model

# %%
mobile=tf.keras.applications.mobilenet.MobileNet()
# Out:
# Metal device set to: Apple M1
# 2022-03-17 18:28:22.726282: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-17 18:28:22.726576: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...
# 17227776/17225924 [==============================] - 32s 2us/step

# %% [markdown]
# * Creating a model
# * Training a model
# * Test or validate a model
# * Predict the model

# %% [markdown]
# # Pre-processing of the image

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(dirc,target_size=(224,224))

# %%
plt.imshow(img)

# %% [markdown]
# # Three kind of image preprocessing

# %%
resized_img=image.img_to_array(img)
final_image=np.expand_dims(resized_img,axis=0)#need fourth dimension
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions=mobile.predict(final_image)
# Out:
# 2022-03-17 18:46:00.578648: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-17 18:46:00.581229: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-03-17 18:46:00.703599: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
print(predictions)
# Out:
# [[1.42833278e-05 6.86250569e-05 4.04534421e-06 6.06484991e-06
#   1.10515548e-05 8.87507758e-06 1.51228858e-06 6.24010181e-06
#   4.32463057e-05 7.60031980e-06 3.17452873e-07 2.27520331e-07
#   1.08105411e-07 6.07155698e-06 7.49149152e-08 6.25624295e-07
#   1.05263862e-05 3.03954930e-05 1.49298503e-05 7.48185073e-07
#   2.05332003e-06 1.13335932e-06 5.34867070e-07 3.57101817e-05
#   4.78586571e-06 1.23047714e-08 1.57359125e-06 1.01631815e-06
#   5.58881538e-07 3.90906098e-06 5.03641104e-07 7.13664292e-07
#   1.12012253e-06 3.54686023e-07 1.74040125e-07 2.16806748e-05
#   5.26820850e-06 3.46995421e-07 3.44775287e-07 1.81958774e-06
#   3.19609012e-06 2.12340353e-07 7.37470813e-08 1.06539835e-06
#   1.94664449e-06 8.27788185e-08 1.01682745e-05 2.53509779e-06
#   2.28826536e-07 7.63074759e-09 3.02975604e-06 5.33728344e-05
#   1.81548585e-05 1.51884274e-06 3.94116739e-08 8.04450428e-06
#   3.89934200e-07 6.45011028e-07 2.36211054e-06 7.31158650e-07
# ...

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# ...
# 40960/35363 [==================================] - 0s 3us/step
# [[('n02110185', 'Siberian_husky', 0.58323723), ('n02109961', 'Eskimo_dog', 0.22531153), ('n02110063', 'malamute', 0.056799944), ('n03482405', 'hamper', 0.022925252), ('n02909870', 'bucket', 0.017185524)]]

# %%
plt.imshow(img)
